# %% [markdown]
# <a href="https://colab.research.google.com/github/Jittiya/DWDM21/blob/main/%E0%B8%AA%E0%B8%AD%E0%B8%9A%20analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #เพื่อใช้ทำงานกับข้อมูลที่เป็นรูปแบบตาราง
import os

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/midterm data 2022'

# %%
data1 = pd.read_csv(os.path.join(path,'customer-info.csv'))
data1
# Out:
#         id first_name  last_name                            email  gender  \
# 0        1     Sherye  Mallinson               smallinson0@360.cn  Female
# 1        3   Rosalind   Gabbitis               rgabbitis2@ftc.gov   Woman
# 2        5   Cristina      Suett             csuett4@e-recht24.de  Female
# 3        9     Amelie      Braid               abraid8@seesaa.net  Female
# 4       12     Philly   McCurrie           pmccurrieb@tinyurl.com  Female
# ...    ...        ...        ...                              ...     ...
# 4995  4261     Peadar    Hengoed            phengoed78@spiegel.de     NaN
# 4996  4262       Noel     Durant            ndurant79@behance.net     NaN
# 4997  4263       Dita    Rampage            drampage7a@senate.gov     NaN
# 4998  4264      Sloan  Kasparski               skasparski7b@ow.ly     NaN
# 4999  4265     Arlene   Glanders  aglanders7c@merriam-webster.com     NaN
#
#              DOB Place_ofBirth
# 0      1/20/1993      Zimbabwe
# ...

# %%
data1.isnull().any()  # ตรวจสอบหาค่า missing
# Out:
# id               False
# first_name       False
# last_name        False
# email             True
# gender            True
# DOB               True
# Place_ofBirth     True
# dtype: bool

# %%
data1.dropna()
# Out:
#         id first_name    last_name                     email  gender  \
# 0        1     Sherye    Mallinson        smallinson0@360.cn  Female
# 1        3   Rosalind     Gabbitis        rgabbitis2@ftc.gov   Woman
# 2        5   Cristina        Suett      csuett4@e-recht24.de  Female
# 3        9     Amelie        Braid        abraid8@seesaa.net  Female
# 7       24      Janis    Botterell        jbotterelln@360.cn  Female
# ...    ...        ...          ...                       ...     ...
# 4946  4989      Bruis       Scally     bscallyrg@answers.com    Male
# 4947  4991     Shermy      Vossgen       svossgenri@dmoz.org    Male
# 4948  4992     Kahlil      Breslin     kbreslinrj@utexas.edu    Male
# 4949  4993      Mikel  Illingworth  millingworthrk@weibo.com    Male
# 4950  4994     Maison      Luberti  mlubertirl@google.com.au    Male
#
#              DOB Place_ofBirth
# 0      1/20/1993      Zimbabwe
# 1       8/5/1975   Philippines
# 2      6/24/1999     Indonesia
# ...

# %%
data_nomissing = data1.sort_values(by=['id'])
data_nomissing
# Out:
#         id first_name    last_name                     email  gender  \
# 0        1     Sherye    Mallinson        smallinson0@360.cn  Female
# 2487     2   Zaccaria       Firsby     zfirsby1@geocities.jp    Male
# 1        3   Rosalind     Gabbitis        rgabbitis2@ftc.gov   Woman
# 2488     4        Saw        Adamo           sadamo3@msu.edu    Male
# 2        5   Cristina        Suett      csuett4@e-recht24.de  Female
# ...    ...        ...          ...                       ...     ...
# 2482  4996        Row        Jersh    rjershrn@imageshack.us  Female
# 2483  4997     Shalne     Leyfield       sleyfieldro@irs.gov  Female
# 2484  4998     Kellie        Chagg        kchaggrp@upenn.edu  Female
# 2485  4999    Gwenora     Milliere     gmilliererq@jimdo.com  Female
# 2486  5000      Faith  Van Leeuwen  fvanleeuwenrr@unicef.org  Female
#
#              DOB   Place_ofBirth
# 0      1/20/1993        Zimbabwe
# 2487   8/18/1974     Philippines
# 1       8/5/1975     Philippines
# ...

# %%
set(data_nomissing['gender'])
# Out:
# {'F', 'Female', 'M', 'Male', 'Man', 'W', 'Woman', nan}

# %%
data_nomissing[['gender']] = data_nomissing[['gender']].fillna()
