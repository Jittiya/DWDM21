# %% [markdown]
# <a href="https://colab.research.google.com/github/Jittiya/DWDM21/blob/main/Chapter6_Association_Rules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/DWDM2021_DATA'
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv(os.path.join(path,'reduced_marketbasket.csv'), encoding='latin1')

# %%
data
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## [Q] มีประเทศสาขาของ supermarket นี้ทั้งหมดกี่ประเทศ

# %%
set(data['Country'])
# Out:
# {'Australia',
#  'Austria',
#  'Bahrain',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Channel Islands',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'EIRE',
#  'European Community',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hong Kong',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Lebanon',
#  'Lithuania',
#  'Malta',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'RSA',
#  'Saudi Arabia',
#  'Singapore',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'USA',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Unspecified'}

# %%
len(set(data['Country']))
# Out:
# 38

# %% [markdown]
# ## [HW13] วาดกราฟสรุปจำนวน items และ ยอดขายของแต่ละประเทศ

# %%
set(data['Description'])
# Out:
# {nan,
#  'COOKING SET RETROSPOT',
#  'CINAMMON & ORANGE WREATH',
#  'SPACEBOY MINI RUCKSACK',
#  'ICON MUG REVOLUTIONARY',
#  'HANGING HEART MIRROR DECORATION ',
#  'REGENCY TEA PLATE ROSES ',
#  'BLACK VINTAGE EARRINGS',
#  'OPULENT VELVET SET/3 CANDLES',
#  'SET/6 BEAD COASTERS GAUZE BAG GOLD',
#  'WHITE SKULL HOT WATER BOTTLE ',
#  'FELTCRAFT CUSHION OWL',
#  'KNITTED UNION FLAG HOT WATER BOTTLE',
#  'wet',
#  'FRENCH BLUE METAL DOOR SIGN 6',
#  'BROWN CHECK CAT DOORSTOP ',
#  ' TOADSTOOL BEDSIDE LIGHT ',
#  'DOLLY GIRL CHILDRENS EGG CUP',
#  'ICE CREAM BUBBLES',
#  'TREASURE AHOY WALL ART',
#  'PIN CUSHION BABUSHKA RED',
#  'LARGE BLACK DIAMANTE HAIRSLIDE',
#  'PINK FLY SWAT',
#  'SMALL BLUE PROVENCAL CERAMIC BALL',
#  'CREAM DELPHINIUM ARTIFICIAL FLOWER',
#  'RED PUDDING SPOON',
#  'VINTAGE KEEPSAKE BOX PARIS DAYS',
#  'JUMBO BAG WOODLAND ANIMALS',
#  'TIGRIS EYE CHUNKY CHARM BRACELET',
#  'PAPER LANTERN 5 POINT SEQUIN STAR',
#  'GOLD COSMETICS BAG WITH BUTTERFLY',
# ...

# %%
len(set(data['Description']))
# Out:
# 4224

# %%
from matplotlib import pyplot as plt
